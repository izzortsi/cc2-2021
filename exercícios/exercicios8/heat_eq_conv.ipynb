# %%
import torch
import pygame
import numpy as np
import os

# Directory for saving frames

frame_directory = "frames"
os.makedirs(frame_directory, exist_ok=True)

# Ensure that CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Simulation parameters
width, height = 400, 400
Nx, Ny = 100, 100
dx, dy = 1.0 / Nx, 1.0 / Ny
dt = 0.01  # Time step
viscosity = 0.02

x_center_1, y_center_1 = 0.5, 0.5  # Center of the 1st Gaussian
x_center_2, y_center_2 = 1.5, 0.5  # Center of the 2nd Gaussian

sigma_1 = 0.10  # Standard deviation of the 1st Gaussian
sigma_2 = 0.20  # Standard deviation of the 2nd Gaussian

magnitude = 200  # Magnitude of the temperature increase

# Initialize the temperature array with two Gaussian distributions

X, Y = torch.meshgrid(torch.linspace(0, 2, Nx), torch.linspace(0, 1, Ny))

# %%
gaussian_field_1 = magnitude * torch.exp(-((X - x_center_1)**2 + (Y - y_center_1)**2) / (2 * sigma_1**2))
gaussian_field_2 = magnitude * torch.exp(-((X - x_center_2)**2 + (Y - y_center_2)**2) / (2 * sigma_2**2))
# plt.matshow(gaussian_field_1
#             + gaussian_field_2)
# plt.show()
T = (200 + gaussian_field_1 + gaussian_field_2).unsqueeze(0).unsqueeze(1).to(device)

# %%
T.shape
# Out:
# torch.Size([1, 1, 100, 100])

# %%
T_pad = torch.functional.F.pad(T, (0, 0, 0, 0), mode="circular")

# %%
T_pad.shape
# Out:
# torch.Size([1, 1, 100, 100])

# %%
def kernel(a_x, a_y, dt):
    return dt*torch.tensor([
                        [0, a_y, 0],
                        [a_x, -2*(a_x + a_y), a_x],
                        [0, a_y, 0]
                        ], dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(1)

# %%
a_x = viscosity / dx**2
a_y = viscosity / dy**2
k = kernel(a_x, a_y, dt)

# %%
laplacian = torch.nn.functional.conv2d(T_pad, k, stride=1, padding = 1)
laplacian.shape
# Out:
# torch.Size([1, 1, 100, 100])

# %%
k
# Out:
# tensor([[[[ 0.,  2.,  0.],
#           [ 2., -8.,  2.],
#           [ 0.,  2.,  0.]]]], device='cuda:0')

# %%
class HeatEquationSolver(torch.nn.Module):
    def __init__(self, T, kernel, dt, dx, dy, viscosity):
        self.T = T
        self.kernel = kernel
        self.dt = dt
        self.dx = dx
        self.dy = dy
        self.viscosity = viscosity

    def forward(self, T):
        # Pad the temperature array
        T_pad = torch.clone(self.T)
        T = torch.clone(self.T)
        T_pad = torch.functional.F.pad(T_pad, (0, 0, 0, 0), mode="circular")
        # Compute the Laplacian
        laplacian = torch.nn.functional.conv2d(T_pad, self.kernel, stride=1, padding = 1)

        
        

        # Compute the new temperature
        T += self.dt * laplacian
        self.T = torch.clone(T)
        return T

# %%
# Pygame setup
pygame.init()
screen = pygame.display.set_mode((width, height))
clock = pygame.time.Clock()

running = True
frame_number = 0
update_skip = 2
MULT = 4
solver = HeatEquationSolver(T, k, dt, dx, dy, viscosity)
last_T = solver.T
while running:

    with torch.no_grad():
        for i in range(MULT):
            last_T = solver.forward(last_T)
        # T = solver.forward()
        # solver.step()
        # print(torch.allclose(solver.T, last_T))
        print(torch.max(solver.T), torch.min(solver.T))
        # Transfer data to CPU for visualization and convert to NumPy
        # T_cpu = solver.T.repeat(1, 3, 1, 1)

        T_cpu = last_T.cpu().detach().squeeze(1).squeeze(0).numpy()
        print(T_cpu.shape, T_cpu.min())
        T_color = T_cpu - np.min(T_cpu)
        T_color = T_color / np.max(T_color)
        T_color = np.uint8(255 * T_color)
        # print(T_color.shape, np.max(T_color))
        from matplotlib import pyplot as plt
        plt.imshow(T_color)
        plt.savefig(f"frame_{frame_number:04d}.png")

        # T_cpu = solver.T.cpu().squeeze(1).numpy()
        # Visualization
        for i in range(Nx):
            for j in range(Ny):
                color = T_color[i, j]
                # print(T_color[i, j])
                # color = min(0, max(0, int(255 * color)))
                # pygame.draw.rect(screen, (color, color, color), (i * width / Nx, j * height / Ny, width / Nx, height / Ny))

        # pygame.surfarray.blit_array(screen, T_cpu)
        # pygame.display.flip()
        clock.tick(60)
        
        # Save frame
        # pygame.image.save(screen, os.path.join(frame_directory, f"frame_{frame_number:04d}.png"))
        frame_number += 1
        # print(frame_number)
        # Check for Pygame quit events
        # for event in pygame.event.get():
        #     if event.type == pygame.QUIT:
        #         running = False

    pygame.quit()
# Out:
# tensor(399.6693, device='cuda:0') tensor(170.7421, device='cuda:0')
# (100, 100) 170.74214
# tensor(399.4666, device='cuda:0') tensor(147.6604, device='cuda:0')
# (100, 100) 147.66042
# tensor(399.2644, device='cuda:0') tensor(129.2012, device='cuda:0')
# (100, 100) 129.2012
# tensor(399.0627, device='cuda:0') tensor(114.2479, device='cuda:0')
# (100, 100) 114.24794
# tensor(398.8615, device='cuda:0') tensor(101.9878, device='cuda:0')
# (100, 100) 101.98782
# tensor(398.6607, device='cuda:0') tensor(91.8217, device='cuda:0')
# (100, 100) 91.82166
# tensor(398.4604, device='cuda:0') tensor(83.3024, device='cuda:0')
# (100, 100) 83.30244
# tensor(398.2606, device='cuda:0') tensor(76.0928, device='cuda:0')
# (100, 100) 76.0928
# tensor(398.0612, device='cuda:0') tensor(69.9353, device='cuda:0')
# (100, 100) 69.93534
# tensor(397.8622, device='cuda:0') tensor(64.6316, device='cuda:0')
# (100, 100) 64.6316
# tensor(397.6638, device='cuda:0') tensor(60.0270, device='cuda:0')
# (100, 100) 60.02698
# tensor(397.4659, device='cuda:0') tensor(56.0000, device='cuda:0')
# (100, 100) 55.99996
# tensor(397.2684, device='cuda:0') tensor(52.4541, device='cuda:0')
# (100, 100) 52.454098
# tensor(397.0714, device='cuda:0') tensor(49.3122, device='cuda:0')
# (100, 100) 49.3122
# tensor(396.8748, device='cuda:0') tensor(46.5120, device='cuda:0')
# (100, 100) 46.51197
# tensor(396.6787, device='cuda:0') tensor(44.0027, device='cuda:0')
# (100, 100) 44.002747
# tensor(396.4831, device='cuda:0') tensor(41.7430, device='cuda:0')
# (100, 100) 41.743004
# (100, 100) 15.951915
# tensor(390.4542, device='cuda:0') tensor(15.6389, device='cuda:0')
# (100, 100) 15.638927
# tensor(390.2728, device='cuda:0') tensor(15.3380, device='cuda:0')
# (100, 100) 15.337966
# tensor(390.0917, device='cuda:0') tensor(15.0483, device='cuda:0')
# (100, 100) 15.048349
# tensor(389.9110, device='cuda:0') tensor(14.7695, device='cuda:0')
# (100, 100) 14.76945
# tensor(389.7308, device='cuda:0') tensor(14.5007, device='cuda:0')
# (100, 100) 14.500686
# tensor(389.5509, device='cuda:0') tensor(14.2415, device='cuda:0')
# (100, 100) 14.241514
# tensor(389.3715, device='cuda:0') tensor(13.9914, device='cuda:0')
# (100, 100) 13.991432
# tensor(389.1924, device='cuda:0') tensor(13.7500, device='cuda:0')
# (100, 100) 13.74997
# tensor(389.0137, device='cuda:0') tensor(13.5167, device='cuda:0')
# (100, 100) 13.516691
# tensor(388.8354, device='cuda:0') tensor(13.2912, device='cuda:0')
# (100, 100) 13.291185
# tensor(388.6575, device='cuda:0') tensor(13.0731, device='cuda:0')
# (100, 100) 13.073072
# tensor(388.4800, device='cuda:0') tensor(12.8620, device='cuda:0')
# (100, 100) 12.861995
# tensor(388.3029, device='cuda:0') tensor(12.6576, device='cuda:0')
# (100, 100) 12.657617
# tensor(388.1262, device='cuda:0') tensor(12.4596, device='cuda:0')
# (100, 100) 12.459624
# tensor(387.9498, device='cuda:0') tensor(12.2677, device='cuda:0')
# (100, 100) 12.267726
# tensor(387.7739, device='cuda:0') tensor(12.0816, device='cuda:0')
# (100, 100) 12.081643
# tensor(387.5983, device='cuda:0') tensor(11.9011, device='cuda:0')
# (100, 100) 11.901116
# tensor(387.4231, device='cuda:0') tensor(11.7259, device='cuda:0')
# (100, 100) 11.7259
# tensor(387.2483, device='cuda:0') tensor(11.5558, device='cuda:0')
# (100, 100) 11.555762
# tensor(387.0738, device='cuda:0') tensor(11.3905, device='cuda:0')
# (100, 100) 11.390488
# tensor(386.8998, device='cuda:0') tensor(11.2299, device='cuda:0')
# (100, 100) 11.229871
# tensor(386.7261, device='cuda:0') tensor(11.0737, device='cuda:0')
# (100, 100) 11.073716
# tensor(386.5528, device='cuda:0') tensor(10.9218, device='cuda:0')
# (100, 100) 10.921843
# tensor(386.3799, device='cuda:0') tensor(10.7741, device='cuda:0')
# (100, 100) 10.7740755
# tensor(386.2073, device='cuda:0') tensor(10.6302, device='cuda:0')
# (100, 100) 10.63025
# tensor(386.0351, device='cuda:0') tensor(10.4902, device='cuda:0')
# (100, 100) 10.490211
# tensor(385.8633, device='cuda:0') tensor(10.3538, device='cuda:0')
# (100, 100) 10.353811
# tensor(385.6919, device='cuda:0') tensor(10.2209, device='cuda:0')
# (100, 100) 10.22091
# tensor(385.5208, device='cuda:0') tensor(10.0914, device='cuda:0')
# (100, 100) 10.091376
# tensor(385.3501, device='cuda:0') tensor(9.9651, device='cuda:0')
# (100, 100) 9.965082
# tensor(385.1797, device='cuda:0') tensor(9.8419, device='cuda:0')
# (100, 100) 9.841908
# tensor(385.0097, device='cuda:0') tensor(9.7217, device='cuda:0')
# (100, 100) 9.721741
# tensor(384.8401, device='cuda:0') tensor(9.6045, device='cuda:0')
# (100, 100) 9.60447
# tensor(384.6708, device='cuda:0') tensor(9.4900, device='cuda:0')
# (100, 100) 9.489994
# tensor(384.5019, device='cuda:0') tensor(9.3782, device='cuda:0')
# (100, 100) 9.378213
# tensor(384.3333, device='cuda:0') tensor(9.2690, device='cuda:0')
# (100, 100) 9.269033
# tensor(384.1651, device='cuda:0') tensor(9.1624, device='cuda:0')
# (100, 100) 9.162364
# tensor(383.9973, device='cuda:0') tensor(9.0581, device='cuda:0')
# (100, 100) 9.058121
# tensor(383.8298, device='cuda:0') tensor(8.9562, device='cuda:0')
# (100, 100) 8.956223
# tensor(383.6627, device='cuda:0') tensor(8.8566, device='cuda:0')
# (100, 100) 8.85659
# tensor(383.4959, device='cuda:0') tensor(8.7591, device='cuda:0')
# (100, 100) 8.75915
# tensor(383.3294, device='cuda:0') tensor(8.6638, device='cuda:0')
# (100, 100) 8.663829
# tensor(383.1634, device='cuda:0') tensor(8.5706, device='cuda:0')
# (100, 100) 8.5705595
# tensor(382.9976, device='cuda:0') tensor(8.4793, device='cuda:0')
# (100, 100) 8.479276
# tensor(382.8322, device='cuda:0') tensor(8.3899, device='cuda:0')
# (100, 100) 8.3899145
# tensor(382.6672, device='cuda:0') tensor(8.3024, device='cuda:0')
# (100, 100) 8.302416
# tensor(382.5025, device='cuda:0') tensor(8.2167, device='cuda:0')
# (100, 100) 8.216723
# tensor(382.3381, device='cuda:0') tensor(8.1328, device='cuda:0')
# (100, 100) 8.132781
# tensor(382.1741, device='cuda:0') tensor(8.0505, device='cuda:0')
# (100, 100) 8.050536
# tensor(382.0104, device='cuda:0') tensor(7.9699, device='cuda:0')
# (100, 100) 7.969938
# tensor(381.8471, device='cuda:0') tensor(7.8909, device='cuda:0')
# (100, 100) 7.890936
# tensor(381.6841, device='cuda:0') tensor(7.8135, device='cuda:0')
# (100, 100) 7.8134847
# tensor(381.5215, device='cuda:0') tensor(7.7375, device='cuda:0')
# (100, 100) 7.7375383
# tensor(381.3591, device='cuda:0') tensor(7.6631, device='cuda:0')
# (100, 100) 7.663054
# tensor(381.1971, device='cuda:0') tensor(7.5900, device='cuda:0')
# (100, 100) 7.5899897
# tensor(381.0355, device='cuda:0') tensor(7.5183, device='cuda:0')
# (100, 100) 7.5183043
# tensor(380.8742, device='cuda:0') tensor(7.4480, device='cuda:0')
# (100, 100) 7.4479604
# tensor(380.7132, device='cuda:0') tensor(7.3789, device='cuda:0')
# (100, 100) 7.37892
# tensor(380.5525, device='cuda:0') tensor(7.3111, device='cuda:0')
# (100, 100) 7.311147
# tensor(380.3922, device='cuda:0') tensor(7.2446, device='cuda:0')
# (100, 100) 7.2446074
